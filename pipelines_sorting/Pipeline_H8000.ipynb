# %%
import spikeinterface.full as si
from spikeinterface.sorters import get_default_sorter_params, get_sorter_params_description
import probeinterface as pi
from spikeinterface_gui import run_mainwindow
from pathlib import Path
import json
import woodsort
import warnings

# %%
# Spike sorting pipeline for the H7100 dataset
# Experimenter: Trisha Narayanan 
# Acquired: Dec 2024 - May 2025

### Parameters set manually ### 

# path to the recording folder (the folder containing the OpenEphys folder YYYY-MM-DD_hh-mm-ss)
#recfolder_path ='/home/avadher/SIDB_Datastore/Trisha/Raw/H7100/H7113/H7113-250604'

run_spike_sorting = True # set to True to run sorting and analyzer, False if using previously saved analyzer
extract_data = True # set to True to extract additional data (tracking, LFP, etc.)

data_path = Path('/home/avadher/Data/Trisha/')
rec_name = 'H8003-260112'

# set parameters for probe
shank_groups = [0, 1] # specify which groups in the xml file are shanks to be sorted (0-base)
probe_manufacturer = "cambridgeneurotech"
probe_name = "ASSY-156-H7" 

# set parameters for spike sorting
sorter = "mountainsort5"
#sorter = "kilosort4"
n_jobs = 12  # number of CPU cores to run everything on 
analyzer_metrics_path = 'params/default_analyzer_metrics.json' # list of metrics for Analyzer to compute 

# set parameters for tracking 
ttl_channel = 65 # channel in DAT file where camera TTL pulses are registered (0-base)
column_names=['x_left','y_left','x_right','y_right']  # keep the same names but change order as recorded
pixel_width = 0.1304  # size of one pixel in cm, get from video by typing pixelwidth in terminal 
min_spacing = 3  # minimum spacing between two LEDs in cm 
max_spacing = 8  # maximum spacing between two LEDs in cm 


### parameters set automatically ### 

# Set paths 
data_path = Path(data_path)
rec_path = data_path / rec_name
processed_path = rec_path / 'Processed'
analyzer_metrics_path = Path(woodsort.__file__).parent / analyzer_metrics_path
spikesorting_folder_name = f"{rec_name}_sorting_{sorter}"
spikesorting_path = processed_path / spikesorting_folder_name
analyzer_folder_name = f"{rec_name}_analyzer_{sorter}"
analyzer_path = processed_path / analyzer_folder_name

# Set the number for cores for parallel processing 
si.set_global_job_kwargs(n_jobs=n_jobs) 

# Ignore annoying warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
### Spike sorting ### 

if run_spike_sorting:
    
    # Load recording and probe, preprocess and fill channel indices from Neuroscope
    recording = si.read_openephys(rec_path, stream_id='0')
    probe = pi.get_probe(manufacturer=probe_manufacturer, probe_name=probe_name) # pi.list_all_probes() to list all probes 
    
    recording = woodsort.openephys.process_with_neuroscope(
        recording=recording, 
        probe_or_probegroup=probe,
        session_path=rec_path,
        save_path=processed_path,
        shank_groups=shank_groups, 
        remove_bad_channels=True,  # SET TO TRUE
        plot_probe=True,
        plot_range=[200, 200.05])
    
    # Run spike sorting
    sorting = si.run_sorter(
        recording=recording, 
        sorter_name=sorter, 
        remove_existing_folder=True, 
        folder=spikesorting_path)
    
    ## Compute analyzer
    analyzer_metrics = json.load(open(analyzer_metrics_path))
    si.create_sorting_analyzer(
        recording=recording,
        sorting=sorting,
        format="binary_folder",
        folder=analyzer_path,
        overwrite=True,
    ).compute(analyzer_metrics)
# Out:
# Using XML file: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording1/continuous/Acquisition_Board-100.Rhythm Data/continuous.xml
# Probe updated with Neuroscope mapping
# Applying high-pass filter (300-6000 Hz)...
# Detecting and removing bad channels...
# Bad channel IDs (0-based Neuroscope index): [2, 4, 12, 62, 54, 56, 58]
# Channel mapping saved to /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/ChannelMapping.csv
#
# write_binary_recording
# engine=process - n_jobs=12 - samples_per_chunk=30,000 - chunk_memory=3.20 MiB - total_memory=38.45 MiB - chunk_duration=1.00s
# Using training recording of duration 300 sec with the sampling mode uniform
# *** MS5 Elapsed time for SCHEME2 get_sampled_recording_for_training: 1.248 seconds ***
# Running phase 1 sorting
# Number of channels: 28
# Number of timepoints: 9000000
# Sampling frequency: 30000.0 Hz
# Channel 0: [  4. 400.]
# Channel 1: [  4.5 450. ]
# Channel 2: [  2. 200.]
# Channel 3: [ 0.5 50. ]
# Channel 4: [  7. 700.]
# Channel 5: [-24.5 475. ]
# Channel 6: [-23. 325.]
# Channel 7: [-24. 425.]
# Channel 8: [-21.5 175. ]
# Channel 9: [-25.5 575. ]
# Channel 10: [-27. 725.]
# Channel 11: [-20.5  75. ]
# Channel 12: [-26.5 675. ]
# Channel 13: [  5.5 550. ]
# Channel 14: [  1. 100.]
# Channel 15: [  2.5 250. ]
# Channel 16: [-25. 525.]
# Channel 17: [-23.5 375. ]
# Channel 18: [-27.5 775. ]
# Channel 19: [-21. 125.]
# Channel 20: [-26. 625.]
# Channel 21: [-22.5 275. ]
# Channel 22: [0. 0.]
# Channel 23: [-20.  25.]
# Channel 24: [  1.5 150. ]
# Channel 25: [  6.5 650. ]
# Channel 26: [  5. 500.]
# Channel 27: [  3. 300.]
# Loading traces
# *** MS5 Elapsed time for load_traces: 0.000 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 200
# [[0, 1, 5, 6, 7, 9, 13, 15, 16, 17, 21, 26, 27], [0, 1, 5, 6, 7, 9, 13, 16, 17, 20, 21, 26, 27], [2, 3, 6, 8, 11, 14, 15, 17, 19, 21, 23, 24, 27], [2, 3, 8, 11, 14, 19, 22, 23, 24], [4, 9, 10, 12, 13, 16, 18, 20, 25], [0, 1, 5, 6, 7, 9, 13, 16, 17, 20, 25, 26, 27], [0, 1, 2, 5, 6, 7, 8, 15, 17, 21, 24, 26, 27], [0, 1, 5, 6, 7, 9, 13, 15, 16, 17, 21, 26, 27], [2, 3, 6, 8, 11, 14, 15, 19, 21, 22, 23, 24, 27], [0, 1, 4, 5, 7, 9, 10, 12, 13, 16, 20, 25, 26], [4, 9, 10, 12, 13, 18, 20, 25], [2, 3, 8, 11, 14, 15, 19, 22, 23, 24], [4, 9, 10, 12, 13, 16, 18, 20, 25, 26], [0, 1, 4, 5, 7, 9, 10, 12, 13, 16, 17, 20, 25, 26], [2, 3, 8, 11, 14, 15, 19, 21, 22, 23, 24], [0, 2, 6, 7, 8, 11, 14, 15, 17, 19, 21, 24, 27], [0, 1, 4, 5, 7, 9, 12, 13, 16, 17, 20, 25, 26], [0, 1, 2, 5, 6, 7, 13, 15, 16, 17, 21, 26, 27], [4, 10, 12, 18, 20, 25], [2, 3, 8, 11, 14, 15, 19, 21, 22, 23, 24, 27], [1, 4, 5, 9, 10, 12, 13, 16, 18, 20, 25, 26], [0, 1, 2, 6, 7, 8, 14, 15, 17, 19, 21, 24, 27], [3, 8, 11, 14, 19, 22, 23, 24], [2, 3, 8, 11, 14, 19, 22, 23, 24], [2, 3, 6, 8, 11, 14, 15, 19, 21, 22, 23, 24, 27], [4, 5, 9, 10, 12, 13, 16, 18, 20, 25, 26], [0, 1, 5, 6, 7, 9, 12, 13, 16, 17, 20, 25, 26], [0, 1, 2, 5, 6, 7, 8, 15, 17, 19, 21, 24, 27]]
#
# m = 0 (nbhd size: 13)
# m = 1 (nbhd size: 13)
# m = 2 (nbhd size: 13)
# m = 3 (nbhd size: 9)
# m = 4 (nbhd size: 9)
# m = 5 (nbhd size: 13)
# m = 6 (nbhd size: 13)
# m = 7 (nbhd size: 13)
# m = 8 (nbhd size: 13)
# m = 9 (nbhd size: 13)
# m = 10 (nbhd size: 8)
# m = 11 (nbhd size: 10)
# m = 12 (nbhd size: 10)
# m = 13 (nbhd size: 14)
# m = 14 (nbhd size: 11)
# m = 15 (nbhd size: 13)
# m = 16 (nbhd size: 13)
# m = 17 (nbhd size: 13)
# m = 18 (nbhd size: 6)
# m = 19 (nbhd size: 12)
# m = 20 (nbhd size: 12)
# m = 21 (nbhd size: 13)
# m = 22 (nbhd size: 8)
# m = 23 (nbhd size: 9)
# m = 24 (nbhd size: 13)
# m = 25 (nbhd size: 11)
# m = 26 (nbhd size: 13)
# m = 27 (nbhd size: 13)
# Detected 70757 spikes
# *** MS5 Elapsed time for detect_spikes: 1.411 seconds ***
# Removing duplicate times
# *** MS5 Elapsed time for remove_duplicate_times: 0.001 seconds ***
# Extracting 70584 snippets
# *** MS5 Elapsed time for extract_snippets: 0.335 seconds ***
# Computing PCA features with npca=84
# *** MS5 Elapsed time for compute_pca_features: 3.758 seconds ***
# Isosplit6 clustering with npca_per_subdivision=10
# Found 48 clusters
# *** MS5 Elapsed time for isosplit6_subdivision_method: 11.174 seconds ***
# Computing templates
# *** MS5 Elapsed time for compute_templates: 0.642 seconds ***
# Determining optimal alignment of templates
# Template alignment converged.
# Align templates offsets:  [-4 -3  1  1  0  3  1  3 -1  0  0  1  4  0  0  4  1  0  2  0  0  3  0  1
#  -2 -2 -2 -1 -2 -5 -3  4  0 -1  3  0  0  4  0 -5 -3  1 -1 -3 -1  0 -1  0]
# *** MS5 Elapsed time for align_templates: 0.560 seconds ***
# Aligning snippets
# *** MS5 Elapsed time for align_snippets: 0.299 seconds ***
# Clustering aligned snippets
# Computing PCA features with npca=84
# *** MS5 Elapsed time for compute_pca_features: 2.608 seconds ***
# Isosplit6 clustering with npca_per_subdivision=10
# *** MS5 Elapsed time for isosplit6_subdivision_method: 11.734 seconds ***
# Found 38 clusters after alignment
# Computing templates
# *** MS5 Elapsed time for compute_templates: 0.618 seconds ***
# Offsetting times to peak
# Offsets to peak: [ -4  -3   1   1 -20   3   1   2   0   0   1   0   0  -5  -2  -2   0   4
#    1   3  -1   0   0   4  -1  -3  -2   3  -5   1   0  -3  -1  -3  -1  -1
#    0   2]
# *** MS5 Elapsed time for determine_offsets_to_peak: 0.002 seconds ***
# Sorting times
# *** MS5 Elapsed time for sorting times: 0.001 seconds ***
# Removing out of bounds times
# *** MS5 Elapsed time for removing out of bounds times: 0.000 seconds ***
# Reordering units
# *** MS5 Elapsed time for reordering units: 0.001 seconds ***
# Creating sorting object
# *** MS5 Elapsed time for creating sorting object: 0.004 seconds ***
# *** MS5 Elapsed time for SCHEME2 sorting_scheme1: 33.209 seconds ***
# *** MS5 Elapsed time for SCHEME2 get_times_labels_from_sorting: 0.005 seconds ***
# Loading training traces
# *** MS5 Elapsed time for SCHEME2 training_recording.get_traces: 0.082 seconds ***
# Training classifier
# *** MS5 Elapsed time for SCHEME2 training classifier step 1: 0.015 seconds ***
# Adding snippets from phase 1 sorting
# Fitting models
# *** MS5 Elapsed time for SCHEME2 fitting models: 15.851 seconds ***
# Chunk size: 119.04763333333334 sec
# Time chunk 1 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.000 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 40973 spikes in chunk 1 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.768 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.460 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.359 seconds ***
# Time chunk 2 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 40477 spikes in chunk 2 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.025 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.396 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.009 seconds ***
# Time chunk 3 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 37720 spikes in chunk 3 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.907 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.300 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.009 seconds ***
# Time chunk 4 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 36118 spikes in chunk 4 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.806 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.425 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 5 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 35157 spikes in chunk 5 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.767 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.351 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 6 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 35489 spikes in chunk 6 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.572 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.316 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 7 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 46965 spikes in chunk 7 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.954 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.467 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 8 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 43952 spikes in chunk 8 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.634 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.461 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 9 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 37501 spikes in chunk 9 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.925 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.408 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 10 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 32354 spikes in chunk 10 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.848 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.348 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 11 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 41148 spikes in chunk 11 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.037 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.430 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.009 seconds ***
# Time chunk 12 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 37640 spikes in chunk 12 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.163 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.400 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 13 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 36176 spikes in chunk 13 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.880 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.484 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 14 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.008 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 34407 spikes in chunk 14 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.927 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.445 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.011 seconds ***
# Time chunk 15 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 35779 spikes in chunk 15 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.977 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.353 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 16 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 40694 spikes in chunk 16 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.003 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.448 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 17 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.008 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 36908 spikes in chunk 17 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.888 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.464 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 18 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 32154 spikes in chunk 18 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.898 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.392 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 19 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 35500 spikes in chunk 19 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.905 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.431 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 20 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 36978 spikes in chunk 20 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.878 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.381 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.012 seconds ***
# Time chunk 21 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 46512 spikes in chunk 21 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.126 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.522 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 22 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 45621 spikes in chunk 22 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.093 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.459 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 23 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 44133 spikes in chunk 23 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.889 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.419 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.014 seconds ***
# Time chunk 24 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 25546 spikes in chunk 24 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.985 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.231 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 25 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 32035 spikes in chunk 25 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.150 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.284 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 26 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 32783 spikes in chunk 26 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.894 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.369 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 27 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 25592 spikes in chunk 27 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.966 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.114 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 28 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 25537 spikes in chunk 28 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.902 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.054 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 29 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 23217 spikes in chunk 29 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.883 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.129 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 30 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 21193 spikes in chunk 30 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.872 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.118 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 31 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 22989 spikes in chunk 31 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.985 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.095 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.012 seconds ***
# Time chunk 32 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 23397 spikes in chunk 32 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.897 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.128 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 33 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 25137 spikes in chunk 33 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.129 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.162 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 34 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.008 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 24719 spikes in chunk 34 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.041 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.222 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 35 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 24757 spikes in chunk 35 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.802 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.183 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 36 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 28102 spikes in chunk 36 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.892 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.201 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 37 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 26921 spikes in chunk 37 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.097 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.244 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 38 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 23736 spikes in chunk 38 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.896 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.176 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 39 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 28282 spikes in chunk 39 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.962 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.310 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 40 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 53119 spikes in chunk 40 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.914 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.418 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.011 seconds ***
# Time chunk 41 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 33241 spikes in chunk 41 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.987 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.301 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 42 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 16254 spikes in chunk 42 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.657 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.142 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 43 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.008 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 22758 spikes in chunk 43 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.881 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.100 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 44 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 19504 spikes in chunk 44 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.860 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.206 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 45 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 17653 spikes in chunk 45 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.964 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.072 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 46 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 18894 spikes in chunk 46 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.032 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.068 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 47 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 37322 spikes in chunk 47 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.968 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.409 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 48 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 49792 spikes in chunk 48 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.005 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.505 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 49 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 30640 spikes in chunk 49 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 3.086 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.399 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 50 of 87
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 7, 17], [1, 5, 7], [2, 8], [3, 11, 23], [4, 10, 12], [1, 5, 26], [6, 27], [0, 1, 7], [2, 8, 24], [9, 13], [4, 10], [3, 11, 14], [4, 12, 25], [9, 13, 16], [11, 14, 19], [15, 21], [13, 16, 26], [0, 17], [18], [14, 19, 24], [20, 25], [15, 21, 27], [22, 23], [3, 22, 23], [8, 19, 24], [12, 20, 25], [5, 16, 26], [6, 21, 27]]
#
# Scheme 2 detected 25877 spikes in chunk 50 of 87
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 2.959 seconds ***
# ...
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.325 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.455 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 75 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 14969 spikes in chunk 75 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.248 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.034 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 76 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 26298 spikes in chunk 76 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.311 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.539 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.006 seconds ***
# Time chunk 77 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 34360 spikes in chunk 77 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.350 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.564 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 78 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 21148 spikes in chunk 78 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.280 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.461 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.005 seconds ***
# Time chunk 79 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 24131 spikes in chunk 79 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.288 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.486 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.010 seconds ***
# Time chunk 80 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 30733 spikes in chunk 80 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.331 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.470 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 81 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 19047 spikes in chunk 81 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.264 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.360 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.005 seconds ***
# Time chunk 82 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 37051 spikes in chunk 82 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.366 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.598 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Time chunk 83 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.004 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 26938 spikes in chunk 83 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.313 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.476 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 84 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 22321 spikes in chunk 84 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.289 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.389 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.009 seconds ***
# Time chunk 85 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.006 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 23685 spikes in chunk 85 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.295 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.458 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.005 seconds ***
# Time chunk 86 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 33052 spikes in chunk 86 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.346 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.502 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 87 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 33082 spikes in chunk 87 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.344 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.489 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.007 seconds ***
# Time chunk 88 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.005 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 26222 spikes in chunk 88 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.317 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.481 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.009 seconds ***
# Time chunk 89 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.007 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 16319 spikes in chunk 89 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.258 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.250 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.004 seconds ***
# Time chunk 90 of 90
# Loading traces
# *** MS5 Elapsed time for SCHEME2 loading traces: 0.008 seconds ***
# Detecting spikes
#
# Adjacency for detect spikes with channel radius 50
# [[0, 12, 23], [1, 11, 24], [2, 8], [3, 10, 21], [4, 7, 18], [5, 6], [5, 6, 25], [4, 7, 26], [2, 8, 14], [9], [3, 10, 13], [1, 11, 15], [0, 12, 16], [10, 13, 17], [8, 14, 19], [11, 15, 22], [12, 16], [13, 17, 25], [4, 18], [14, 19, 27], [20], [3, 21, 27], [15, 22, 26], [0, 23, 28], [1, 24, 28], [6, 17, 25], [7, 22, 26], [19, 21, 27], [23, 24, 28]]
#
# Scheme 2 detected 19490 spikes in chunk 90 of 90
# *** MS5 Elapsed time for SCHEME2 detecting spikes: 0.245 seconds ***
# Extracting and classifying snippets
# *** MS5 Elapsed time for SCHEME2 extracting and classifying snippets: 2.440 seconds ***
# Updating events
# Removing duplicates
# *** MS5 Elapsed time for SCHEME2 updating events: 0.008 seconds ***
# Concatenating results
# *** MS5 Elapsed time for SCHEME2 concatenating results: 0.004 seconds ***
# Perorming label mapping
# *** MS5 Elapsed time for SCHEME2 label mapping: 0.000 seconds ***
# Creating sorting object
# *** MS5 Elapsed time for SCHEME2 creating sorting object: 0.149 seconds ***
# estimate_sparsity (workers: 12 processes):   0%|          | 0/10329 [00:00<?, ?it/s]
# compute_waveforms (workers: 12 processes):   0%|          | 0/10329 [00:00<?, ?it/s]
# noise_level (workers: 12 processes):   0%|          | 0/20 [00:00<?, ?it/s]
# /home/avadher/.conda/envs/woodsort/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# Fitting PCA:   0%|          | 0/83 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/83 [00:00<?, ?it/s]
# Compute : spike_amplitudes + spike_locations (workers: 12 processes):   0%|          | 0/10329 [00:00<?, ?it/s…
# /home/avadher/.conda/envs/woodsort/lib/python3.10/site-packages/numpy/_core/_methods.py:223: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/avadher/.conda/envs/woodsort/lib/python3.10/site-packages/numpy/_core/_methods.py:181: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/avadher/.conda/envs/woodsort/lib/python3.10/site-packages/numpy/_core/_methods.py:215: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# noise_level (workers: 12 processes):   0%|          | 0/20 [00:00<?, ?it/s]
# calculate_pc_metrics:   0%|          | 0/83 [00:00<?, ?it/s]

# %%
### Manual curation ###

analyzer = si.load_sorting_analyzer(analyzer_path)
run_mainwindow(analyzer, mode="desktop", curation=True)

# %%
### Get other data from the recording ###

if extract_data:
    
    # get epochs
    epochs = woodsort.openephys.get_epochs(
        rec_path, 
        save_path=processed_path)
    
    # get events 
    events = woodsort.openephys.get_events(
        rec_path,
        save_path=processed_path,
        epochs=[2]) # specify which epoch to extract events from (skip to extract from all epochs)
    
    # get OpenEphys metadata
    woodsort.openephys.get_openephys_metadata(
            data_path, 
            save_path=processed_path)
    
    # align tracking
    aligned_tracking = woodsort.tracking.align_tracking_bonsai(
        recfolder_path=rec_path, 
        ttl_channel=ttl_channel, 
        column_names=column_names, 
        save_path=processed_path)
    
    # process tracking
    processed_tracking = woodsort.tracking.process_tracking_bonsai(
            aligned_tracking,   
            pixel_width=pixel_width,      # conversion factor: cm per pixel
            min_spacing=min_spacing,      # minimum allowed LED spacing (cm)
            max_spacing=max_spacing,  
            save_path=processed_path,  # maximum allowed LED spacing (cm)
            plot=True)             # whether to show diagnostic plot
    
    # Extract LFP
    woodsort.lfp.extract_lfp_openephys(rec_path, save_path=processed_path)
# Out:
# Extracting start and end times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording1
# Extracting start and end times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording2
# Extracting start and end times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording3
#
# Epoch timestamps saved to: /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/EpochTimestamps.csv
#
# Extracting event times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording1
# Extracting event times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording2
# Extracting event times: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording3
#
# Event timestamps saved to: /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/EventTimestamps.csv
#
#
# Collecting sync messages...
# Sync metadata written to: /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/MetadataOpenephys.txt
#
#
# Aligning Bonsai tracking data...
#
# Recording path: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording1
# TTL pulses:         25357
# Bonsai frames:      25356
# Duration of tracking the epoch via Bonsai: 633.96 seconds.
# Duration of tracking the epoch via TTL: 633.91 seconds.
# Trimming 1 extra TTL pulses at the end
#
# Recording path: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording2
# TTL pulses:         216084
# Bonsai frames:      216083
# Duration of tracking the epoch via Bonsai: 5402.77 seconds.
# Duration of tracking the epoch via TTL: 5402.13 seconds.
# Trimming 1 extra TTL pulses at the end
#
# Recording path: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording3
# TTL pulses:         170946
# Bonsai frames:      170941
# Duration of tracking the epoch via Bonsai: 4274.14 seconds.
# Duration of tracking the epoch via TTL: 4273.67 seconds.
# Trimming 5 extra TTL pulses at the end
# Warning: many missing frames!
# Tracking saved to: /home/avadher/Data/Trisha/H8003/TrackingAligned.csv
#
# Tracking aligned.
#
#
# Processing aligned tracking
# 55.8% frames removed due to LED spacing outside [3, 8] cm
# Tracking saved to: /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/TrackingProcessed.csv
#
# Tracking processed.
#
#
# [1] recording folder: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording1
# Extracting LFP: 100%|██████████| 192/192 [00:26<00:00,  7.13it/s]
# [2] recording folder: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording2
# Extracting LFP: 100%|██████████| 1622/1622 [03:46<00:00,  7.16it/s]
# [3] recording folder: /home/avadher/Data/Trisha/H8003/H8003-260112/2026-01-12_19-49-32/Record Node 101/experiment1/recording3
# Extracting LFP: 100%|██████████| 1284/1284 [02:58<00:00,  7.18it/s]
# Done. Processed 3 recording folder(s).
# Merged 3 LFP files into /home/avadher/Data/Trisha/H8003/H8003-260112/Processed/continuous.lfp.
# Component LFP files removed.
# Copied XML file.
# LFP extraction done.
